# %% [markdown]
# # Cars4U - Problem Statement - Joey Arato

# %% [markdown]
# ## Load Libraries

# %%
# Install nb_black if not already installed, commenting out for now since its installed on my system
# pip install nb_black

# %%
# Helps with good practices in the code (note to self comment cannot be on the same line)
# %load_ext nb_black

# Data manipulation libraries ---------
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)   #remove limit for dispalying columns
pd.set_option('display.max_rows', 200)   #sets a limit of 200 for displaying the max number of rows

#---------------------------------------------------------------

# Data viz libraries
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

#---------------------------------------------------------------

# Machine learning libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
#from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import tmean

#---------------------------------------------------------------

# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Dataset and review its characteristics

# %%
data = pd.read_csv("used_cars_data.csv")
data.shape
# Out:
# (7253, 14)

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
df = data  # copy data into a new data frame so as not to inadvertantly change the orginal data set

# %%
df.info()  # review the basic info on the data set, looks like we have several objects lets see if we can reclaim some memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7078 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.memory_usage()  # check the memory usabe of the data
# Out:
# Index                  128
# S.No.                58024
# Name                 58024
# Location             58024
# Year                 58024
# Kilometers_Driven    58024
# Fuel_Type            58024
# Transmission         58024
# Owner_Type           58024
# Mileage              58024
# Engine               58024
# Power                58024
# Seats                58024
# New_Price            58024
# Price                58024
# dtype: int64

# %%
# tried converting name to catagory and found it used more memory switched back to object, leaving code will look at this again later on
# df["Name"] = df["Name"].astype("category")
# df["Name"] = df["Name"].astype("object")

# %%
# df.memory_usage()   # checking memory after changing to catagory

# %%
df.describe().T  #   Lets get a look at the numerical data stats
# Out:
#                     count          mean           std      min      25%  \
# S.No.              7253.0   3626.000000   2093.905084     0.00   1813.0
# Year               7253.0   2013.365366      3.254421  1996.00   2011.0
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.0
# Seats              7200.0      5.279722      0.811660     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
#
#                         50%       75%        max
# S.No.               3626.00   5439.00     7252.0
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53416.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0

# %%
# Describe details about the objects in the data set, pushing to the other view since i think its easier with more columns
df.describe(include=("object")).T
# Out:
#              count unique                     top  freq
# Name          7253   2041  Mahindra XUV500 W8 2WD    55
# Location      7253     11                  Mumbai   949
# Fuel_Type     7253      5                  Diesel  3852
# Transmission  7253      2                  Manual  5204
# Owner_Type    7253      4                   First  5952
# Mileage       7251    450               17.0 kmpl   207
# Engine        7207    150                 1197 CC   732
# Power         7078    385                  74 bhp   280
# New_Price     1006    625              63.71 Lakh     6

# %% [markdown]
# ## Lets check for nulls

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# New_Price            6247
# Price                1234
# Power                 175
# Seats                  53
# Engine                 46
# Mileage                 2
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# dtype: int64

# %%
# Lets see what precentage of the data set is null for New_Price
6247 / 7253
# Out:
# 0.8612987729215497

# %% [markdown]
# We can see there arent a ton of overly concenring nulls outside of New_Price. However in New_price 86% of the data set is null. Will drop this column. For Power, Seats, Engine and Mileage will fill in the data with Null values. In this next section will at stripping out 'kmpl' and similare from Mileage, 'CC from Engine' & 'BHP' from Power. Those columns will then be convereted to numerical values.

# %%
df.drop(["New_Price"], axis=1, inplace=True)  # Droping the New_Price column

# 2820  1198 CC    86.8 bhp    5.0   3.55
# 3620  1598 CC   103.5 bhp    5.0   5.00
# 264   2987 CC  254.79 bhp    5.0  61.29
# 1062  1086 CC   68.05 bhp    5.0   2.20
# 2943  1498 CC   89.84 bhp    5.0   5.45
# 7152  1199 CC      84 bhp    5.0    NaN
# 4803  1582 CC  126.32 bhp    5.0   5.85
# 6575  1493 CC     100 bhp    7.0    NaN
# 651   2143 CC  201.15 bhp    5.0  37.93
# 2787  2993 CC     258 bhp    5.0  34.54
# 5250  1599 CC   103.2 bhp    5.0   2.60
# 385   1497 CC   117.3 bhp    5.0   8.75
# 2859   999 CC      67 bhp    5.0   4.80
# 6191  1798 CC     160 bhp    5.0    NaN
# 6883  1197 CC   81.83 bhp    5.0    NaN
# 248   1120 CC      70 bhp    5.0   4.75
# 520    998 CC   67.04 bhp    5.0   2.79
# 1044  1968 CC  187.74 bhp    5.0  25.00
# 4787  1598 CC   103.5 bhp    5.0   5.84
# 3126  1197 CC    83.1 bhp    5.0   5.49
# 737   1495 CC      94 bhp    5.0   2.00
# 4057  1968 CC  174.33 bhp    5.0  21.50
# 3745  1248 CC    88.5 bhp    5.0  11.39
# 5727  1995 CC     190 bhp    5.0  29.30
# 3988  1396 CC   69.01 bhp    5.0   2.70
# 2189  1984 CC     132 bhp    5.0  12.00
# 5278  3198 CC     197 bhp    7.0  33.50
# 441   1399 CC   98.79 bhp    8.0   3.75
# 3351  1396 CC      90 bhp    5.0   4.50
# 7220  1248 CC   73.75 bhp    5.0    NaN
# 5536  1497 CC     118 bhp    5.0   5.25
# 5937  2179 CC     120 bhp    8.0   6.40
# 3983  1591 CC   121.3 bhp    5.0   9.03
# 5215  1499 CC     110 bhp    5.0   7.72
# 6786  1497 CC     118 bhp    5.0    NaN
# 3214  1591 CC   121.3 bhp    5.0   4.40
# 2055  2494 CC   100.6 bhp    7.0  11.62
# 1913  1968 CC  174.33 bhp    5.0  20.12

# %%
convert = ["Mileage", "Engine", "Power"]

# %%
# Function to convert Mileage, Engine & Power Column to a numerical value. Will strip out any non-nuemerical data, we know we there are two nulls in Mileage those will be replaced with nan


def object_to_num(mileage):
    if isinstance(mileage, str):
        return float(
            mileage.replace("kmpl", "")
            .replace("km/kg", "")
            .replace("CC", "")
            .replace("bhp", "")
        )
    else:
        return np.nan


for col in convert:
    df[col] = df[col].apply(object_to_num)

df.sample(10)
# Out:
#       S.No.                                  Name    Location  Year  \
# 3007   3007           Hyundai i20 Asta Option 1.2   Hyderabad  2017
# 3178   3178  Volkswagen Polo Petrol Highline 1.2L      Mumbai  2011
# 4007   4007                       Honda Brio S MT     Chennai  2013
# 4752   4752                  Ford Figo Diesel EXI       Delhi  2013
# 2311   2311                     BMW X5 xDrive 30d  Coimbatore  2016
# 2068   2068                  Hyundai Accent GLE 1     Chennai  2007
# 5611   5611                Maruti Wagon R LX BSII       Delhi  2006
# 4429   4429                  Volvo XC60 D4 Summum   Hyderabad  2012
# 1448   1448              Hyundai Verna 1.6 VTVT S      Jaipur  2015
# 6802   6802                Hyundai i10 Sportz 1.2   Hyderabad  2012
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 3007              19860    Petrol       Manual      First    18.60  1197.0
# 3178              20000    Petrol       Manual      First    16.47  1198.0
# 4007              58581    Petrol       Manual      First    19.40  1198.0
# 4752              54000    Diesel       Manual      First    20.00  1399.0
# 2311              17738    Diesel    Automatic      First    15.30  2993.0
# 2068              55000    Petrol       Manual      First    13.20  1495.0
# 5611              86000    Petrol       Manual     Second    18.90   998.0
# 4429              86000    Diesel    Automatic     Second    14.70  1985.0
# 1448              89000    Petrol       Manual      First    17.01  1591.0
# 6802              54982    Petrol       Manual      First    20.36  1197.0
#
#        Power  Seats  Price
# 3007   81.83    5.0   6.95
# 3178   73.90    5.0   3.50
# 4007   86.80    5.0   3.49
# 4752   68.05    5.0   2.55
# 2311  258.00    5.0  54.45
# 2068   94.00    5.0   2.65
# 5611   67.10    5.0   1.00
# 4429  163.00    5.0  18.25
# 1448  121.30    5.0   7.50
# 6802   78.90    5.0    NaN

# %%
df.info()  # We can see Mileage, Engine and Power have all been convereted to Floats at this point
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 736.8+ KB

# %%
# Serial number is the same as index dropping the entire column
df.drop(["S.No."], axis=1, inplace=True)

# %%
df.sample(20)
# Out:
#                                        Name    Location  Year  \
# 2798          Mahindra TUV 300 2015-2019 T8  Coimbatore  2017
# 2653                   Honda Amaze S i-DTEC      Jaipur  2015
# 6988                Nissan Terrano XE 85 PS      Jaipur  2013
# 4882                 Toyota Fortuner 4x2 AT   Hyderabad  2012
# 734                   Maruti Swift VDI BSIV     Kolkata  2012
# 4010                      Maruti A-Star Vxi   Hyderabad  2011
# 5342                  Honda Amaze VX i-VTEC  Coimbatore  2019
# 3913                        Maruti Ritz VDi     Kolkata  2011
# 5316                 Tata Bolt Quadrajet XE   Hyderabad  2016
# 4280                       Renault KWID RXT        Pune  2015
# 1831                    Chevrolet Cruze LTZ   Bangalore  2013
# 1836                 Hyundai i10 Sportz 1.2     Chennai  2010
# 2000  Mahindra Renault Logan 1.4 GLX Petrol        Pune  2008
# 970                         Maruti Ritz VDi   Hyderabad  2012
# 5770                 Mahindra XUV500 W6 2WD      Mumbai  2015
# 4450   Toyota Innova 2.5 G4 Diesel 8-seater   Hyderabad  2015
# 2346                  Mahindra Xylo D2 BSIV     Chennai  2013
# 5367                    Honda City 1.5 S MT     Kolkata  2009
# 2117          Maruti Baleno Delta Automatic       Kochi  2018
# 7191        Renault Duster 110PS Diesel RxZ       Delhi  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 2798              49404    Diesel       Manual      First    18.49  1493.0
# 2653              60207    Diesel       Manual      First    25.80  1498.0
# 6988              54000    Diesel       Manual      First    20.45  1461.0
# 4882             158000    Diesel    Automatic      First    12.55  2982.0
# 734               52241    Diesel       Manual      First    25.20  1248.0
# 4010              53766    Petrol       Manual      First    19.00   998.0
# 5342              16573    Petrol       Manual      First    17.80  1198.0
# 3913              35888    Diesel       Manual      First    21.10  1248.0
# 5316             100303    Diesel       Manual      First    22.95  1248.0
# 4280              28000    Petrol       Manual      First    25.17   799.0
# 1831              64000    Diesel       Manual     Second    17.30  1998.0
# 1836              77000    Petrol       Manual     Second    20.36  1197.0
# 2000               2200    Petrol       Manual      First    15.70  1390.0
# 970               96000    Diesel       Manual      First    21.10  1248.0
# 5770              48000    Diesel       Manual      First    16.00  2179.0
# 4450             147848    Diesel       Manual      First    12.80  2494.0
# 2346             234000    Diesel       Manual     Second    14.00  2489.0
# 5367              31423    Petrol       Manual      First    17.00  1497.0
# 2117              21684    Petrol    Automatic      First    21.40  1197.0
# 7191              62000    Diesel       Manual      First    19.01  1461.0
#
#        Power  Seats  Price
# 2798  100.00    7.0   7.36
# 2653   98.60    5.0   5.50
# 6988   83.80    5.0    NaN
# 4882  168.50    7.0  17.49
# 734    74.00    5.0   2.90
# 4010   66.10    5.0   2.70
# 5342   86.70    5.0   9.31
# 3913   73.90    5.0   1.89
# 5316   74.00    5.0   3.70
# 4280   53.30    5.0   2.65
# 1831  163.70    5.0   6.50
# 1836   78.90    5.0   2.10
# 2000   75.00    5.0   2.30
# 970    73.90    5.0   3.60
# 5770  140.00    7.0   9.45
# 4450  102.00    8.0  13.20
# 2346   95.00    8.0   3.50
# 5367  118.00    5.0   1.99
# 2117   83.10    5.0   7.89
# 7191  108.45    5.0    NaN

# %% [markdown]
# ## Univariate & Bivariate Analysis

# %% [markdown]
# ### Lets look at Price

# %%
sns.displot(data=df, x="Price", kde=True)

# %%
# sns.boxplot(data=df, x="Price", y="Year", color="blue")
sns.boxplot(data=df, x="Price", color="red")
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# ### Lets do a log transformation on Price and see what it looks like
# I dont want to change this column entirely yet so im going to copy the dataframe and do the transformation on the new frame for now

# %%
df_price_log = df
sns.displot(np.log(df_price_log.Price), kde=True)

# %%
df.groupby("Location").Price.median().sort_values(ascending=False)
# Out:
# Location
# Coimbatore    8.305
# Bangalore     6.850
# Kochi         6.710
# Ahmedabad     5.900
# Hyderabad     5.800
# Mumbai        5.750
# Delhi         5.500
# Chennai       4.500
# Jaipur        4.250
# Pune          4.250
# Kolkata       3.750
# Name: Price, dtype: float64

# %% [markdown]
# ### Price Analysis
#
# * Prices are heavily skewed toward the lower end of the spectrum
# * We do see a handful of outliers at the higher end of the spectrum
# * We can see that Coimbatore followed by Bangalore and Kochi have the highest median price with Coimbatore being more than double that of Kolkate.
# * We can see that Chennai, Jaipur, Pune & Kolkata are all on the lower end of median pricing and might be markets to stay away from

# %% [markdown]
# ### Lets look at our bivariate analysis for other interesting data interactions

# %%
plt.figure(figsize=(18, 9))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Heat Map Analysis
# * We can see strong positive correlations between Engine and Power & Power & Price
# * Slightly strong positive correlations between Engine and Price
# * Interestingly Power is a better indicator of price than the Engine, will focus on using Power instead of Engine

# %%
sns.pairplot(data=df, hue="Price", diag_kind="kde")

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data=df, y="Year", x="Power", hue="Price")
plt.show()

# %% [markdown]
# ## EDA
#
# * some stuff about price and what not

# %% [markdown]
# ## Get Dummies
#
# Will create dummy values for these columns 'Fuel_Type', 'Transmission' & 'Owner_Type' to one hots

# %%
# df = pd.get_dummies(
#    df, columns=["Fuel_Type", "Transmission", "Owner_Type"], drop_first=True
# )

# %%
# df.sample(10)

# %%
# df.describe().T

# %%
# df.info()
