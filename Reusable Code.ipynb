# %% [markdown]
# ### Code functions that will be reused throughout the class

# %%
# Libraries and what not

# data libraries
import numpy as np
import pandas as pd

# data viz libraries
import matplotlib.pyplot as plt
import seaborn as sns

#command to tell python to display graphs
# %matplotlib inline

# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('StockData.csv')

# %%
df1 = pd.read_excel('StockData2.xlsx')

# %%
data1 = df.copy() #copy dataframe
data2 = df1.copy() #copy dataframe

# %%
data1.head()
# Out:
#   stock        date  price
# 0  AAPL  08-02-2013 67.854
# 1  AAPL  11-02-2013 68.561
# 2  AAPL  12-02-2013 66.843
# 3  AAPL  13-02-2013 66.716
# 4  AAPL  14-02-2013 66.656

# %%
data2.sample(5)
# Out:
#      stock        date  price
# 4085   ZTS  01-05-2014 30.310
# 1623   SNI  22-07-2014 83.230
# 4343   ZTS  11-05-2015 46.090
# 3397   TJX  05-08-2016 81.980
# 3510   TJX  18-01-2017 76.680

# %%
data1.shape
# Out:
# (5036, 3)

# %%
data2.shape
# Out:
# (5036, 3)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   stock   5036 non-null   object
#  1   date    5036 non-null   object
#  2   price   5036 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 118.2+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   stock   5036 non-null   object
#  1   date    5036 non-null   object
#  2   price   5036 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 118.2+ KB

# %%
data1.describe().T
# Out:
#          count   mean    std    min    25%    50%    75%     max
# price 5036.000 73.057 29.011 28.400 54.067 69.085 79.250 179.260

# %%
data2.describe().T
# Out:
#          count   mean    std    min    25%    50%    75%     max
# price 5036.000 73.057 29.011 28.400 54.067 69.085 79.250 179.260

# %%
data1.describe(include='all').T
# Out:
#          count unique         top  freq   mean    std    min    25%    50%  \
# stock     5036      4         ZTS  1259    NaN    NaN    NaN    NaN    NaN
# date      5036   1259  01-06-2015     4    NaN    NaN    NaN    NaN    NaN
# price 5036.000    NaN         NaN   NaN 73.057 29.011 28.400 54.067 69.085
#
#          75%     max
# stock    NaN     NaN
# date     NaN     NaN
# price 79.250 179.260

# %%
data1.isnull().sum()
# Out:
# stock    0
# date     0
# price    0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['stock', 'date', 'price'], dtype='object')

# %%
data1.value_counts()
# Out:
# stock  date        price
# AAPL   01-02-2016  96.430    1
# TJX    21-03-2013  45.610    1
#        21-04-2017  78.560    1
#        21-04-2016  77.010    1
#        21-04-2015  66.290    1
#                             ..
# SNI    11-03-2013  64.320    1
#        11-02-2016  53.130    1
#        11-02-2015  73.660    1
#        11-02-2014  76.780    1
# ZTS    31-12-2015  47.920    1
# Length: 5036, dtype: int64

# %%
data1['price'].value_counts()
# Out:
# 74.590     8
# 67.160     7
# 75.390     5
# 74.230     5
# 73.490     5
#           ..
# 78.810     1
# 108.700    1
# 122.770    1
# 46.510     1
# 74.870     1
# Name: price, Length: 3776, dtype: int64

# %%
data2.groupby(['stock'])['price'].mean()
# Out:
# stock
# AAPL   109.067
# SNI     71.319
# TJX     66.744
# ZTS     45.099
# Name: price, dtype: float64

# %%
data1.sample()
# Out:
#      stock        date  price
# 3897   ZTS  01-08-2013 30.160

# %%
data1.iloc[[3000,3010],[0,2]]
# Out:
#      stock  price
# 3000   TJX 68.600
# 3010   TJX 67.630

# %%
data1.loc[[100,200],['stock','price']]
# Out:
#     stock  price
# 100  AAPL 60.114
# 200  AAPL 74.257

# %%
data1[data1['price']>100]
# Out:
#      stock        date   price
# 384   AAPL  19-08-2014 100.530
# 385   AAPL  20-08-2014 100.570
# 386   AAPL  21-08-2014 100.580
# 387   AAPL  22-08-2014 101.320
# 388   AAPL  25-08-2014 101.540
# ...    ...         ...     ...
# 1254  AAPL  01-02-2018 167.780
# 1255  AAPL  02-02-2018 160.500
# 1256  AAPL  05-02-2018 156.490
# 1257  AAPL  06-02-2018 163.030
# 1258  AAPL  07-02-2018 159.540
#
# [762 rows x 3 columns]

# %%
data1[100:104]
# Out:
#     stock        date  price
# 100  AAPL  03-07-2013 60.114
# 101  AAPL  05-07-2013 59.631
# 102  AAPL  08-07-2013 59.293
# 103  AAPL  09-07-2013 60.336

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   stock   5036 non-null   object
#  1   date    5036 non-null   object
#  2   price   5036 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 118.2+ KB

# %%
data1['stock'].unique()
# Out:
# array(['AAPL', 'SNI', 'TJX', 'ZTS'], dtype=object)

# %%
data1['stock'].apply(type).value_counts()
# Out:
# <class 'str'>    5036
# Name: stock, dtype: int64

# %%
sns.histplot(data = data2, x = 'price', bins = 10);

# %%
plt.title('Histogram:Example')
plt.xlim(10,200)
plt.ylim(0,1000)
plt.xlabel('Price of Stock')
plt.ylabel('Amount of stock')
sns.histplot(data = data2, x = 'price', color = 'purple', bins = 20)
# Out:
# <AxesSubplot:title={'center':'Histogram:Example'}, xlabel='Price of Stock', ylabel='Amount of stock'>

# %%
plt.title('Histogram:Example')
plt.xlim(10,200)
plt.ylim(0,1600)
plt.xlabel('Price of Stock')
plt.ylabel('Amount of stock')
sns.histplot(data = data2, x = 'price', color = 'purple', binwidth = 10)
# Out:
# <AxesSubplot:title={'center':'Histogram:Example'}, xlabel='Price of Stock', ylabel='Amount of stock'>

# %%
plt.title('Histogram: Price of stock')
plt.xlim(10,200)
plt.ylim(0,1000)
plt.xlabel('Price of Stock')
plt.ylabel('Amount of stock')
sns.histplot(data = data2, x = 'price', color = 'teal', bins = 20, kde = True)
# Out:
# <AxesSubplot:title={'center':'Histogram: Price of stock'}, xlabel='Price of Stock', ylabel='Amount of stock'>

# %%
sns.histplot(data = data1, x = 'price', hue='stock', binwidth = 10);

# %%
g = sns.FacetGrid(data1, col = 'stock')
g.map(sns.histplot, 'price', color = 'orange', kde = True)

# %%
sns.boxplot(data = data1, x = 'price', y = 'stock')
# Out:
# <AxesSubplot:xlabel='price', ylabel='stock'>

# %%
plt.title('Boxplot: Price')
plt.xlim(30,150)
plt.xlabel('Price')
plt.ylabel("Stock")
# ax.legend([])
sns.axes_style('darkgrid')
sns.boxplot(data=df, x ='price', y = 'stock', color='green');

# %%
sns.countplot(data = data1, x = 'stock');

# %%
sns.barplot(data = data1, x = "date", y = 'price', hue = 'stock');

# %%
plt.figure(figsize = (20,7))
sns.countplot(data = data2, x = 'stock');
plt.xticks(rotation = 90) # rotatles the lables on the x axis 90 degrees
sns.set(style='darkgrid') # changes the background grid, darkgrid, whitegrid, white
plt.show() #removes header text

# %%
data1.head()
# Out:
#   stock        date  price
# 0  AAPL  08-02-2013 67.854
# 1  AAPL  11-02-2013 68.561
# 2  AAPL  12-02-2013 66.843
# 3  AAPL  13-02-2013 66.716
# 4  AAPL  14-02-2013 66.656

# %%
sns.lineplot(data = data1, x = 'date', y = 'price')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (15,7))
sns.lineplot(data = data1, x = "date", y = 'price', hue = 'stock')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.scatterplot(data = data1, x = 'date', y = 'price', hue = 'stock', style='stock');

# %%
#sns.lmplot(data = data1, x = 'date', y = 'price', hue = 'stock')

# %%
sns.jointplot(data = data1, x = 'date', y = 'price');

# %%
data1['date'] = pd.to_datetime(data1['date'], dayfirst = True) #KDE requires all axis to be numeric or date time formats

# %%
sns.jointplot(data = data1, x = 'date', y = 'price', kind = 'kde', fill = True);

# %%
sns.violinplot(data = data1, x = 'date', y = 'price', palette = 'bright', orient = 'v');

# %%
# sns.stripplot(data = data1, x = "date", y = 'price', hue = 'stock', jitter = True);

# %%
sns.stripplot(data = data1, x = 'price');

# %%
# sns.swarmplot(data = data2, x = 'date', y = 'price', hue = 'stock');

# %%
sns.pairplot(data = data1, vars = ['date', 'price'], hue = 'stock');

# %%
sns.pairplot(data = data1, vars = ['date', 'price'], corner = True)

# %%
sns.heatmap(data = data1[['price','date']].corr(), annot = True, cbar = False);
